# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp

# %%
data = pd.read_csv("evaluacion_lunes/data/data_canton.csv", encoding="latin-1", sep=";")

# %%
data[' Partido '].unique()
# Out:
# array(['Alianza "Participa con Igualdad"', 'PS-FA', 'Alianza PAIS',
#        'Pachakutik', 'Avanza', 'CREO', 'MPD', 'SUMA', 'PRIAN', 'PSC',
#        'Movimiento Agrario de IntegraciÃ³n San Miguel', 'PRE',
#        'Movimiento Social Conservador del Carchi',
#        'Movimiento IntegraciÃ³n DemocrÃ¡tica del Carchi', 'PSP',
#        'Movimiento SantarroseÃ±o Unido Revolucionario',
#        'Movimiento de Identidad Provincial', 'Alianza PaÃ\xads',
#        'Movimiento AcciÃ³n Regional por la Equidad',
#        'Movimiento Alianza Popular Latinoamericana',
#        'Movimiento EspÃ\xadndola  Unida',
#        'Movimiento PolÃ\xadtico Pueblo Cambio y Desarrollo',
#        'Movimiento Alianza Fronteriza',
#        'Unidos por Pastaza - Movimiento Cantonal del Pueblo',
#        'Movimiento Frente de Lucha Ciudadana',
#        'Movimiento Ciudadano Cevallense', 'Movimiento AcciÃ³n y Servicio'],
#       dtype=object)

# %%
lista = ['Alianza "Participa con Igualdad"', 'PS-FA', 'Alianza PAIS',
       'Pachakutik', 'Avanza', 'CREO', 'MPD', 'SUMA', 'PRIAN', 'PSC',
       'Movimiento Agrario de IntegraciÃ³n San Miguel', 'PRE',
       'Movimiento Social Conservador del Carchi',
       'Movimiento IntegraciÃ³n DemocrÃ¡tica del Carchi', 'PSP',
       'Movimiento SantarroseÃ±o Unido Revolucionario',
       'Movimiento de Identidad Provincial', 'Alianza PaÃ\xads',
       'Movimiento AcciÃ³n Regional por la Equidad',
       'Movimiento Alianza Popular Latinoamericana',
       'Movimiento EspÃ\xadndola  Unida',
       'Movimiento PolÃ\xadtico Pueblo Cambio y Desarrollo',
       'Movimiento Alianza Fronteriza',
       'Unidos por Pastaza - Movimiento Cantonal del Pueblo',
       'Movimiento Frente de Lucha Ciudadana',
       'Movimiento Ciudadano Cevallense', 'Movimiento AcciÃ³n y Servicio']

# %%
partido = data[' Partido ']

# %%
plt.figure(figsize=(20,10))
plt.title(u"Alcaldes", fontsize = 30)
for l in lista:
    partido.value_counts().plot(kind='kde')

plt.legend(lista)
plt.show()
